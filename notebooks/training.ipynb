# %% [markdown]
# # Model Training Notebook
#
# This notebook triggers model training and persistence.

# %%
from backend.app.models.train_model import train_and_persist_models

train_and_persist_models()
